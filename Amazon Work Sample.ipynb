# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\trist\Downloads\amazon-orders.csv.csv")

# %%
df
# Out:
#      Order Date             Order ID     Website Shipment Date Order Status  \
# 0     1/20/2016  115-4540401-5793010  Amazon.com     1/21/2016      Shipped
# 1     8/17/2016  110-5675332-5892214  Amazon.com     8/18/2016      Shipped
# 2     8/19/2016  110-2946455-1071417  Amazon.com     8/20/2016      Shipped
# 3     8/24/2016  110-6422828-6082631  Amazon.com     8/25/2016      Shipped
# 4    10/10/2016  104-7940937-9780209  Amazon.com    10/11/2016      Shipped
# ..          ...                  ...         ...           ...          ...
# 220   1/17/2023  114-7977479-1317813  Amazon.com     1/17/2023      Shipped
# 221   1/17/2023  114-1440306-0843441  Amazon.com     1/18/2023      Shipped
# 222   1/17/2023  114-3404693-9265866  Amazon.com     1/18/2023      Shipped
# 223   1/25/2023  114-5344728-4296227  Amazon.com     1/27/2023      Shipped
# 224   1/30/2023  114-8217727-4210603  Amazon.com     1/30/2023      Shipped
#
#      Subtotal Shipping Charge Tax Before Promotions Total Promotions  \
# 0    $131.82           $0.00                $10.87            $0.00
# 1      $5.99           $0.00                 $0.00            $0.00
# 2      $9.28           $0.00                 $0.77            $0.00
# 3     $33.24           $0.00                 $2.74            $0.00
# 4     $49.99           $0.00                 $0.00            $0.00
# ..        ...             ...                   ...              ...
# 220   $36.99           $0.00                 $3.05            $0.00
# 221    $7.99           $0.00                 $0.66            $0.00
# 222   $12.95           $0.00                 $1.07            $0.00
# 223   $67.96           $0.00                 $5.61            $0.00
# 224   $74.95           $2.99                 $0.00            $2.99
#
#     Tax Charged Total Charged
# 0       $10.87       $142.69
# 1        $0.00         $5.99
# 2        $0.77        $10.05
# 3        $2.74        $35.98
# 4        $0.00        $49.99
# ..          ...           ...
# 220      $3.05        $40.04
# 221      $0.66         $8.65
# 222      $1.07        $14.02
# 223      $5.61        $73.57
# 224      $0.00        $74.95
#
# [225 rows x 11 columns]

# %%
df.head()
# Out:
#    Order Date             Order ID     Website Shipment Date Order Status  \
# 0   1/20/2016  115-4540401-5793010  Amazon.com     1/21/2016      Shipped
# 1   8/17/2016  110-5675332-5892214  Amazon.com     8/18/2016      Shipped
# 2   8/19/2016  110-2946455-1071417  Amazon.com     8/20/2016      Shipped
# 3   8/24/2016  110-6422828-6082631  Amazon.com     8/25/2016      Shipped
# 4  10/10/2016  104-7940937-9780209  Amazon.com    10/11/2016      Shipped
#
#    Subtotal Shipping Charge Tax Before Promotions Total Promotions  \
# 0  $131.82           $0.00                $10.87            $0.00
# 1    $5.99           $0.00                 $0.00            $0.00
# 2    $9.28           $0.00                 $0.77            $0.00
# 3   $33.24           $0.00                 $2.74            $0.00
# 4   $49.99           $0.00                 $0.00            $0.00
#
#   Tax Charged Total Charged
# 0     $10.87       $142.69
# 1      $0.00         $5.99
# 2      $0.77        $10.05
# 3      $2.74        $35.98
# 4      $0.00        $49.99

# %%
df.shape
# Out:
# (225, 11)

# %%
df = df.fillna(0)

# %%
df.head()
# Out:
#    Order Date             Order ID     Website Shipment Date Order Status  \
# 0   1/20/2016  115-4540401-5793010  Amazon.com     1/21/2016      Shipped
# 1   8/17/2016  110-5675332-5892214  Amazon.com     8/18/2016      Shipped
# 2   8/19/2016  110-2946455-1071417  Amazon.com     8/20/2016      Shipped
# 3   8/24/2016  110-6422828-6082631  Amazon.com     8/25/2016      Shipped
# 4  10/10/2016  104-7940937-9780209  Amazon.com    10/11/2016      Shipped
#
#    Subtotal Shipping Charge Tax Before Promotions Total Promotions  \
# 0  $131.82           $0.00                $10.87            $0.00
# 1    $5.99           $0.00                 $0.00            $0.00
# 2    $9.28           $0.00                 $0.77            $0.00
# 3   $33.24           $0.00                 $2.74            $0.00
# 4   $49.99           $0.00                 $0.00            $0.00
#
#   Tax Charged Total Charged
# 0     $10.87       $142.69
# 1      $0.00         $5.99
# 2      $0.77        $10.05
# 3      $2.74        $35.98
# 4      $0.00        $49.99

# %%
df['Total Charged'] = df['Total Charged'].str.replace('$','').astype(float)
# Out:
# C:\Users\trist\AppData\Local\Temp\ipykernel_27496\860424133.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Total Charged'] = df['Total Charged'].str.replace('$','').astype(float)

# %%
df.head()
# Out:
#    Order Date             Order ID     Website Shipment Date Order Status  \
# 0   1/20/2016  115-4540401-5793010  Amazon.com     1/21/2016      Shipped
# 1   8/17/2016  110-5675332-5892214  Amazon.com     8/18/2016      Shipped
# 2   8/19/2016  110-2946455-1071417  Amazon.com     8/20/2016      Shipped
# 3   8/24/2016  110-6422828-6082631  Amazon.com     8/25/2016      Shipped
# 4  10/10/2016  104-7940937-9780209  Amazon.com    10/11/2016      Shipped
#
#    Subtotal Shipping Charge Tax Before Promotions Total Promotions  \
# 0  $131.82           $0.00                $10.87            $0.00
# 1    $5.99           $0.00                 $0.00            $0.00
# 2    $9.28           $0.00                 $0.77            $0.00
# 3   $33.24           $0.00                 $2.74            $0.00
# 4   $49.99           $0.00                 $0.00            $0.00
#
#   Tax Charged  Total Charged
# 0     $10.87          142.69
# 1      $0.00            5.99
# 2      $0.77           10.05
# 3      $2.74           35.98
# 4      $0.00           49.99

# %%
df['Total Charged'].sum()
# Out:
# 8274.1

# %%
df['Total Charged'].mean()
# Out:
# 36.77377777777777

# %%
df['Total Charged'].median()
# Out:
# 29.15

# %%
df['Total Charged'].max()
# Out:
# 324.49

# %%
df['Total Charged'].min()
# Out:
# 0.0

# %%
df['Tax Charged'] = df['Tax Charged'].str.replace('$','').astype(float)
# Out:
# C:\Users\trist\AppData\Local\Temp\ipykernel_27496\1494548317.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Tax Charged'] = df['Tax Charged'].str.replace('$','').astype(float)

# %%
df.head()
# Out:
#    Order Date             Order ID     Website Shipment Date Order Status  \
# 0   1/20/2016  115-4540401-5793010  Amazon.com     1/21/2016      Shipped
# 1   8/17/2016  110-5675332-5892214  Amazon.com     8/18/2016      Shipped
# 2   8/19/2016  110-2946455-1071417  Amazon.com     8/20/2016      Shipped
# 3   8/24/2016  110-6422828-6082631  Amazon.com     8/25/2016      Shipped
# 4  10/10/2016  104-7940937-9780209  Amazon.com    10/11/2016      Shipped
#
#    Subtotal Shipping Charge Tax Before Promotions Total Promotions  \
# 0  $131.82           $0.00                $10.87            $0.00
# 1    $5.99           $0.00                 $0.00            $0.00
# 2    $9.28           $0.00                 $0.77            $0.00
# 3   $33.24           $0.00                 $2.74            $0.00
# 4   $49.99           $0.00                 $0.00            $0.00
#
#    Tax Charged  Total Charged
# 0        10.87         142.69
# 1         0.00           5.99
# 2         0.77          10.05
# 3         2.74          35.98
# 4         0.00          49.99

# %%
df['Tax Charged'].sum()
# Out:
# 496.7

# %%
df['Tax Charged'].sum()/df['Total Charged'].sum()
# Out:
# 0.06003069820282568

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.head()
# Out:
#   Order Date             Order ID     Website Shipment Date Order Status  \
# 0 2016-01-20  115-4540401-5793010  Amazon.com     1/21/2016      Shipped
# 1 2016-08-17  110-5675332-5892214  Amazon.com     8/18/2016      Shipped
# 2 2016-08-19  110-2946455-1071417  Amazon.com     8/20/2016      Shipped
# 3 2016-08-24  110-6422828-6082631  Amazon.com     8/25/2016      Shipped
# 4 2016-10-10  104-7940937-9780209  Amazon.com    10/11/2016      Shipped
#
#    Subtotal Shipping Charge Tax Before Promotions Total Promotions  \
# 0  $131.82           $0.00                $10.87            $0.00
# 1    $5.99           $0.00                 $0.00            $0.00
# 2    $9.28           $0.00                 $0.77            $0.00
# 3   $33.24           $0.00                 $2.74            $0.00
# 4   $49.99           $0.00                 $0.00            $0.00
#
#    Tax Charged  Total Charged
# 0        10.87         142.69
# 1         0.00           5.99
# 2         0.77          10.05
# 3         2.74          35.98
# 4         0.00          49.99

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
daily_orders = df.groupby('Order Date').sum()['Total Charged']

# %%
daily_orders.head()
# Out:
# Order Date
# 2016-01-20    142.69
# 2016-08-17      5.99
# 2016-08-19     10.05
# 2016-08-24     35.98
# 2016-10-10     49.99
# Name: Total Charged, dtype: float64

# %%
daily_orders.plot.bar(figsize=(25,10), color= '#61D199')
# Out:
# <AxesSubplot:xlabel='Order Date'>
